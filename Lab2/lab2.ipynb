# %%
cd /content/drive/MyDrive/AI-system-Labs/BasicLabs/Lab2
# Out:
# /content/drive/MyDrive/AI-system-Labs/BasicLabs/Lab2

# %%
# !python mnist_custom_conv.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.763753
#
# Test set: Average loss: 0.0541, Accuracy: 9820/10000 (98%)

# %%
# !python mnist_custom_linear.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.763753
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.481111
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.889105
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.675584
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.648862
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.495983
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.541314
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.222395
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.543095
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.271151
# ...

# %%
cd mylinear_cpp_extension
# Out:
# /content/drive/MyDrive/AI-system-Labs/BasicLabs/Lab2/mylinear_cpp_extension

# %%
# !python setup.py install --user
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
# ...

# %%
cd ..

# %%
ls
# Out:
# build/  dist/  mylinear.cpp  mylinear_cpp.egg-info/  setup.py

# %%
cd ..
# Out:
# /content/drive/MyDrive/AI-system-Labs/BasicLabs/Lab2

# %%
# !python mnist_custom_linear_cpp.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.340728
#
# Test set: Average loss: 0.0500, Accuracy: 9836/10000 (98%)
